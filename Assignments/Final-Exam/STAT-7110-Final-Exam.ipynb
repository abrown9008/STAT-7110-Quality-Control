# %% [markdown]
# ## Final Exam
# ### Dr. Austin R. Brown
# ### Kennesaw State University
#
# **DUE: December 11, 2026 by 11:59 PM via D2L**

# %% [markdown]
# ---
# ## Part 1: Harness Strap Dimensions (Hotelling's $T^2$)
#
# ### Instructions
#
# You work for Wagging Trails Pet Co., a manufacturer of harnesses for small dogs. As the quality control manager, your job is to ensure that the harnesses produced meet high standards. Two dimensions impact the comfort and safety of each harness: (1) the chest strap length and (2) the neck strap length. Both straps are cut from the same fabric roll, and temperature or humidity swings in the cutting room can stretch or shrink the fabric enough to affect both dimensions at once -- so you suspect the two dimensions may not be independent of one another. If either dimension is off, the harness may not fit properly, causing discomfort or even safety issues for the dogs.
#
# You have collected data on the chest strap length and neck strap length for a sample of harnesses produced at your primary manufacturing facility. The data are in the file `Harness Data.xlsx`. With these data, I want you to:
#
# ### Q1: Read in the Phase I data, which are contained in Sheet 1 (`ChestStrapPhaseI`) and Sheet 2 (`NeckStrapPhaseI`); note $n = 5$ and $m = 30$. Calculate the mean and standard deviation for both the chest strap length and the neck strap length. (HINT: remember $c_4$!)

# %%
## Part 1, Q1 Code ##

# %% [markdown]
# ### Q2: Using Hotelling's $T^2$ chart, plot a Phase I control chart. Do we have evidence that the multivariate process is in a state of statistical control? Why or why not?

# %%
## Part 1, Q2 Code ##

# %% [markdown]
# ### Q3: If the chart is out-of-control, omit the offending point(s) and replot until statistical control has been achieved. Once achieved, read in the Phase II data, which are contained in Sheet 3 (`ChestStrapPhaseII`) and Sheet 4 (`NeckStrapPhaseII`). Once again, calculate the mean and standard deviation for both the chest strap length and the neck strap length.

# %%
## Part 1, Q3 Code ##

# %% [markdown]
# ### Q4: Using the Phase II Hotelling's $T^2$ chart, plot the Phase II data. Do we still have evidence of statistical control? Why or why not? If not, describe which strategy you would employ to determine which of the two dimensions is causing the process to be out-of-control -- and carry out that strategy.

# %%
## Part 1, Q4 Code ##

# %% [markdown]
# ### Q5: What are some pros and cons of using a multivariate control chart compared to several univariate control charts?

# %% [markdown]
# ---
# ## Part 2: Leash Length Across Three Machines (Boyd's GCC)
#
# ### Instructions
#
# Business has been very good for Wagging Trails Pet Co. The company has decided to expand its product line to include leashes for small dogs, and has purchased three individual, independent machines to manufacture them. The leashes should ideally all be 3.5 feet in length. The Phase I data are contained in the file `Leash Data.xlsx`, Sheet 1 (`PhaseI`). With these data, I want you to:
#
# ### Q1: Calculate the mean and standard deviation for the leash length produced by each machine.

# %%
## Part 2, Q1 Code ##

# %% [markdown]
# ### Q2: Using Boyd's GCC, calculate and report the control limits.

# %%
## Part 2, Q2 Code ##

# %% [markdown]
# ### Q3: Plot a Phase I Boyd's GCC. Do we have evidence that the process has historically been in control? Why or why not? If not, omit the offending point(s) and replot until statistical control has been achieved.

# %%
## Part 2, Q3 Code ##

# %% [markdown]
# ### Q4: Read in the Phase II data, contained in Sheet 2 (`PhaseII`). Calculate the mean and standard deviation for the leash length for each machine.

# %%
## Part 2, Q4 Code ##

# %% [markdown]
# ### Q5: Using Boyd's GCC and the finalized, in-control Phase I limits, plot the Phase II data. Do we have evidence that the process is in control? Why or why not? If not, describe which strategy you would employ to determine which machine is causing the process to be out-of-control -- and carry out that strategy.

# %%
## Part 2, Q5 Code ##

# %% [markdown]
# ### Q6: Describe the main difference between a multivariate process and a multiple stream process.
#
# ### Q7: What is one of the main limitations of Boyd's GCC?

# %% [markdown]
# ---
# ## Part 3: Dog Dish Diameters (Nonparametric CUSUM)
#
# ### Instructions
#
# Wagging Trails Pet Co. has an opportunity to purchase a used machine for manufacturing dog drinking dishes from another company that is going out of business. This machine has been in operation for several years and has a history of occasionally producing nonconforming units. The seller is willing to offer a discount, but the machine may not be worth the investment if it isn't reliable. Specifically, the machine is supposed to manufacture dog drinking dishes with a median diameter of 10 inches. The seller has provided historical data on the diameters of the dishes it has produced, where $n = 6$ and $m = 35$. The data are contained in the file `Dish Data.xlsx`, Sheet 1 (`Diameters`). With these data, I want you to:
#
# ### Q1: Calculate the mean and standard deviation for the dish diameters.

# %%
## Part 3, Q1 Code ##

# %% [markdown]
# ### Q2: Plot a histogram of the row means. Does the data appear to be normally distributed? Why or why not?

# %%
## Part 3, Q2 Code ##

# %% [markdown]
# ### Q3: Using Bakir and Reynolds' Nonparametric CUSUM chart, plot the data. Use $k = 15$ and $h = 6$. Do we have evidence that the process is in control? Why or why not?

# %%
## Part 3, Q3 Code ##

# %% [markdown]
# ### Q4: Give one pro and one con for using a nonparametric method compared to a parametric method.
#
# ### Q5: What is the most important thing you've learned in this class?
